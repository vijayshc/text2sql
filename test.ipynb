# %%
# !ls
# Out:
# KBLaM

# %%
# !python -c "from transformers import pipeline; print(pipeline('sentiment-analysis',device='cuda')('hugging face is the best'))"
# Out:
# 2025-04-16 15:23:21.328252: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744817001.349043     300 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744817001.355220     300 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
# !export WANDB_DISABLED="true"
# !export WANDB_MODE=dryrun
# %env WANDB_MODE=dryrun
# %env HF_TOKEN=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
# !cd KBLaM/ && python experiments/train.py --dataset datasets --encoder_spec all-MiniLM-L6-v2 --N 120000 --B 20 --total_steps 601 --use_cached_embd  --key_embd_src key --use_data_aug --hf_token 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 --llm_type phi3 --hf_model_spec microsoft/Phi-3-mini-4k-instruct
# Out:
# env: WANDB_MODE=dryrun
# env: HF_TOKEN=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
# 2025-04-16 16:17:46.679527: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744820266.703346    1224 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744820266.710216    1224 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cd KBLaM/ && python dataset_generation/generate_kb_embeddings.py --model_name all-MiniLM-L6-v2 --dataset_path /kaggle/working/KBLaM/datasets/gpt_data.json --output_path /kaggle/working/KBLaM/datasets/output
# Out:
# 2025-04-16 16:05:58.011436: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744819558.037225    1039 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744819558.044844    1039 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
# Batches: 100%|███████████████████████████████████| 4/4 [00:00<00:00, 162.19it/s]
#
# Batches: 100%|███████████████████████████████████| 4/4 [00:00<00:00, 171.79it/s]
#
# Batches: 100%|███████████████████████████████████| 4/4 [00:00<00:00, 175.00it/s]
#
# ...
# Batches: 100%|███████████████████████████████████| 4/4 [00:00<00:00, 176.03it/s]
#
# ...

# %%
# !ls KBLaM/datasets/gpt_data.json
# !pwd
# Out:
# KBLaM/datasets/gpt_data.json
# /kaggle/working

# %%
# !mv KBLaM/datasets/enron.json KBLaM/datasets/gpt_data.json

datasets/gpt_data_oai_embd_key.npy

# %%
# !ls -ltr KBLaM/datasets/gpt_data_oai_embd_key.npy
# !mv KBLaM/datasets/gpt_data_oai_embd_key.npy KBLaM/datasets/gpt_data_oai_embd_key.npy1
# !mv KBLaM/datasets/gpt_data_oai_embd_key.npy1/synthetic_data_all-MiniLM-L6-v2_embd_key.npy KBLaM/datasets/gpt_data_oai_embd_key.npy
# !mv KBLaM/datasets/gpt_data_oai_embd_key.npy1/synthetic_data_all-MiniLM-L6-v2_embd_value.npy KBLaM/datasets/gpt_data_oai_embd_value.npy
# Out:
# -rw-r--r-- 1 root root 44691584 Apr 16 15:59 KBLaM/datasets/gpt_data_oai_embd_key.npy
# mv: cannot stat 'KBLaM/datasets/gpt_data_oai_embd_key.npy1/synthetic_data_all-MiniLM-L6-v2_embd_key.npy': No such file or directory
# mv: cannot stat 'KBLaM/datasets/gpt_data_oai_embd_key.npy1/synthetic_data_all-MiniLM-L6-v2_embd_value.npy': No such file or directory

# %%
# !ls -ltr KBLaM/datasets

# !mv KBLaM/datasets/output/synthetic_data_all-MiniLM-L6-v2_embd_key.npy KBLaM/datasets/gpt_data_oai_embd_key.npy
# !mv KBLaM/datasets/output/synthetic_data_all-MiniLM-L6-v2_embd_value.npy KBLaM/datasets/gpt_data_oai_embd_value.npy

# !mv KBLaM/datasets/gpt_data_oai_embd_key.npy KBLaM/datasets/gpt_data_all-MiniLM-L6-v2_embd_key.npy
# !mv KBLaM/datasets/gpt_data_oai_embd_value.npy KBLaM/datasets/gpt_data_all-MiniLM-L6-v2_embd_value.npy
# Out:
# total 202588
# -rw-r--r-- 1 root root      2562 Apr 16 15:08 datasetcard_enron.md
# -rw-r--r-- 1 root root      2051 Apr 16 15:08 datasetcard_synthetic.md
# -rw-r--r-- 1 root root  10664046 Apr 16 15:08 gpt_data.json
# -rw-r--r-- 1 root root 107374110 Apr 16 15:08 synthetic.json
# drwxr-xr-x 2 root root      4096 Apr 16 16:05 gpt_data_oai_embd_key.npy1
# -rw-r--r-- 1 root root  44691584 Apr 16 16:06 gpt_data_all-MiniLM-L6-v2_embd_key.npy
# -rw-r--r-- 1 root root  44691584 Apr 16 16:06 gpt_data_all-MiniLM-L6-v2_embd_value.npy
# drwxr-xr-x 2 root root      4096 Apr 16 16:07 output
# mv: cannot stat 'KBLaM/datasets/gpt_data_oai_embd_key.npy': No such file or directory
# mv: cannot stat 'KBLaM/datasets/gpt_data_oai_embd_value.npy': No such file or directory

# %%
# !pip install huggingface_hub
